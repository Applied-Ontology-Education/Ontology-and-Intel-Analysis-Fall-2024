# %%
from rdflib import * 
process = Graph().parse("ontology-of-intelligence-ops.ttl",format ='ttl')

# %%
print(process.serialize(format = 'ttl'))
# Out:
# @prefix : <http://www.buffalo.edu/ontology-for-ia/2024/9/intelops/> .
# @prefix ns1: <http://www.ontologyrepository.com/CommonCoreOntologies/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# : a owl:Ontology ;
#     owl:imports <http://www.ontologyrepository.com/CommonCoreOntologies/Mid/2024-09-26/MergedAllCoreOntology> .
#
# <https://www.blackcape.io/ontologies/2024/04/analytics/ANZO_SYS000000> a owl:Class ;
#     rdfs:label "Flight Plan"@en ;
#     rdfs:subClassOf [ a owl:Class ;
#             owl:intersectionOf ( [ a owl:Restriction ;
#                         owl:onProperty ns1:is_about ;
#                         owl:someValuesFrom ns1:Aircraft ] [ a owl:Restriction ;
#                         owl:onProperty ns1:prescribes ;
#                         owl:someValuesFrom ns1:ActOfTravel ] ) ],
#         ns1:PlanSpecification .
#
# ...
